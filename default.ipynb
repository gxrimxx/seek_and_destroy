# %% [markdown]
# ## README
#
# This is your ROSJect documentation!
#
# A place to present your ROS Project to the world!
#
# How to customize it:
#
# - Open your ROSJect
#
# - Edit the default jupyter notebook file (**/home/user/notebook_ws/default.ipynb**)
#
# - Close or wait for it to be saved automatically
#
# - Your **Readme** will be updated based on your notebook

# %% [markdown]
# Run the following commands to setup the session:
# cd ~/seek_destroy_ws/
# ./setup_session.sh

# %% [markdown]
# When opening any new terminal, remember to run these:
#
# cd ~/seek_destroy_ws/
# source /opt/ros/humble/setup.bash
# source ~/seek_destroy_ws/install/setup.bash

# %% [markdown]
# export IGN_GAZEBO_SYSTEM_PLUGIN_PATH=/opt/ros/humble/lib/ign_ros2_control/system:$IGN_GAZEBO_SYSTEM_PLUGIN_PATH

# %% [markdown]
# colcon build --symlink-install
#
# ros2 launch rosbot_gazebo simulation.launch.py robot_model:=rosbot

# %% [markdown]
# ## FOR RUNNING SLAM
#
# source /opt/ros/humble/setup.bash
# ros2 launch slam_toolbox online_async_launch.py \
#   slam_params_file:=/home/user/seek_destroy_ws/my_slam_params.yaml \
#   use_sim_time:=true
#
# ### then in rviz:
# Set Fixed Frame to map
# Click Add → By Topic → /map → Map
# Click Add → By Topic → /scan → LaserScan
# Click Add → RobotModel

# %% [markdown]
# ## SETTING NAV2 GOAL
#
# in a new terminal
#
# cd ~/seek_destroy_ws/
# source /opt/ros/humble/setup.bash
# source ~/seek_destroy_ws/install/setup.bash
#
# ros2 launch nav2_bringup navigation_launch.py \
#   use_sim_time:=true \
#   params_file:=$HOME/seek_destroy_ws/src/seek_destroy/config/nav2_params.yaml
#
# In RViz, add:
#
# Add → By Topic → /local_costmap/costmap → Map (shows obstacle inflation in real time)
# Add → By Topic → /global_costmap/costmap → Map
# Add → By Topic → /plan → Path

# %% [markdown]
# ## FOR UPDATING GIT REPO
#
# cd ~/seek_destroy_ws/
# ./update_github.sh "write message here"
#
# this script automatically uploads the jupyter notebook to the seek_destroy_ws, and does git add commit and push

# %% [markdown]
# ## RUNNING EXPLORE LITE
#
# start gazebo, slam, nav2 in three diff terminals and then in the 4th terminal run the following:
#
# cd ~/seek_destroy_ws/
# source /opt/ros/humble/setup.bash
# source install/setup.bash
# ros2 launch explore_lite explore.launch.py
